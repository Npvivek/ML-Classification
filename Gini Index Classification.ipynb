# %%
import pandas as pd
import numpy as np
from pprint import pprint

dataset = pd.read_csv('CarDatabase.csv',
                      names=['Buying Price','Maintenance Price','Number of Doors','Person Capacity',
                             'luggage Boot Size','Safety','class'])


def entropy(target_col):

    elements,counts = np.unique(target_col,return_counts = True)
    entropy = np.sum([np.square(counts[i]/np.sum(counts)) for i in range(len(elements))])
    return 1-entropy 



def InfoGain(data,split_attribute_name,target_name="class"):
  
  
    total_entropy = entropy(data[target_name])
    vals,counts= np.unique(data[split_attribute_name],return_counts=True)
    Weighted_Entropy = np.sum([(counts[i]/np.sum(counts))*entropy(data.where(data[split_attribute_name]==vals[i]).dropna()[target_name]) for i in range(len(vals))])
    Information_Gain = total_entropy - Weighted_Entropy
    return Information_Gain
       



def ID3(data,originaldata,features,target_attribute_name="class",parent_node_class = None):
    
     if len(np.unique(data[target_attribute_name])) <= 1:
        return np.unique(data[target_attribute_name])[0]
    
     elif len(data)==0:
        return np.unique(originaldata[target_attribute_name])[np.argmax(np.unique(originaldata[target_attribute_name],return_counts=True)[1])]
    
    
     elif len(features) ==0:
        return parent_node_class
    
    
     else:
        parent_node_class = np.unique(data[target_attribute_name])[np.argmax(np.unique(data[target_attribute_name],return_counts=True)[1])]
        
        item_values = [InfoGain(data,feature,target_attribute_name) for feature in features] 
        best_feature_index = np.argmax(item_values)
        best_feature = features[best_feature_index]
        tree = {best_feature:{}}
        features = [i for i in features if i != best_feature]
        
        
        for value in np.unique(data[best_feature]):
            value = value
            
            sub_data = data.where(data[best_feature] == value).dropna()
            subtree = ID3(sub_data,dataset,features,target_attribute_name,parent_node_class)
            tree[best_feature][value] = subtree
            
        return(tree)    
                   
    
def predict(query,tree,default = 1):
  
    
    
  
    for key in list(query.keys()):
        if key in list(tree.keys()):
            
            try:
                result = tree[key][query[key]] 
            except:
                return default
  
            
            result = tree[key][query[key]]
            
            if isinstance(result,dict):
                return predict(query,result)

            else:
                return result

        


def train_test_split(dataset): 

 
  training_data = dataset.iloc[:1200].reset_index(drop=True)
  testing_data = dataset.iloc[1200:].reset_index(drop=True)
  return training_data,testing_data

training_data = train_test_split(dataset)[0]
testing_data = train_test_split(dataset)[1] 



def test(data,tree):
    
    queries = data.iloc[:,:-1].to_dict(orient = "records")
    predicted = pd.DataFrame(columns=["predicted"]) 
    
    for i in range(len(data)):
        predicted.loc[i,"predicted"] = predict(queries[i],tree,1.0) 
    print('The prediction accuracy is: ',(np.sum(predicted["predicted"] == data["class"])/len(data))*100,'%')
    





tree = ID3(training_data,training_data,training_data.columns[:-1])
pprint(tree)
test(testing_data,tree)
# Out:
# {'Safety': {'Safety': 'Class',
#             'high': {'Person Capacity': {'average': {'Buying Price': {'high': {'Maintenance Price': {'high': 'acc',
#                                                                                                      'low': 'acc',
#                                                                                                      'med': 'acc',
#                                                                                                      'vhigh': 'unacc'}},
#                                                                       'low': {'Maintenance Price': {'high': {'luggage Boot Size': {'big': 'vgood',
#                                                                                                                                    'med': 'vgood',
#                                                                                                                                    'small': 'acc'}},
#                                                                                                     'low': {'luggage Boot Size': {'big': 'vgood',
#                                                                                                                                   'med': {'Number of Doors': {'average': 'vgood',
#                                                                                                                                                               'less': 'good'}},
#                                                                                                                                   'small': 'good'}},
#                                                                                                     'med': {'luggage Boot Size': {'big': 'vgood',
#                                                                                                                                   'med': {'Number of Doors': {'average': 'vgood',
#                                                                                                                                                               'baverage': 'good',
#                                                                                                                                                               'less': 'good',
#                                                                                                                                                               'more': 'vgood'}},
#                                                                                                                                   'small': 'good'}},
#                                                                                                     'vhigh': 'acc'}},
#                                                                       'med': {'Maintenance Price': {'high': 'acc',
#                                                                                                     'low': {'luggage Boot Size': {'big': 'vgood',
#                                                                                                                                   'med': {'Number of Doors': {'average': 'vgood',
#                                                                                                                                                               'baverage': 'good',
#                                                                                                                                                               'less': 'good',
#                                                                                                                                                               'more': 'vgood'}},
#                                                                                                                                   'small': 'good'}},
#                                                                                                     'med': {'luggage Boot Size': {'big': 'vgood',
#                                                                                                                                   'med': {'Number of Doors': {'average': 'vgood',
#                                                                                                                                                               'less': 'acc',
#                                                                                                                                                               'more': 'vgood'}},
#                                                                                                                                   'small': 'acc'}},
#                                                                                                     'vhigh': 'acc'}},
#                                                                       'vhigh': {'Maintenance Price': {'high': 'unacc',
#                                                                                                       'low': 'acc',
#                                                                                                       'med': 'acc',
#                                                                                                       'vhigh': 'unacc'}}}},
#                                          'less': 'unacc',
#                                          'more': {'Buying Price': {'high': {'Maintenance Price': {'high': 'acc',
#                                                                                                   'low': {'Number of Doors': {'average': 'acc',
#                                                                                                                               'baverage': 'acc',
#                                                                                                                               'less': {'luggage Boot Size': {'big': 'acc',
#                                                                                                                                                              'med': 'acc',
#                                                                                                                                                              'small': 'unacc'}},
#                                                                                                                               'more': 'acc'}},
#                                                                                                   'med': {'Number of Doors': {'average': 'acc',
#                                                                                                                               'baverage': 'acc',
#                                                                                                                               'less': {'luggage Boot Size': {'med': 'acc',
#                                                                                                                                                              'small': 'unacc'}},
#                                                                                                                               'more': 'acc'}},
#                                                                                                   'vhigh': 'unacc'}},
#                                                                    'low': {'Maintenance Price': {'high': {'luggage Boot Size': {'big': 'vgood',
#                                                                                                                                 'med': {'Number of Doors': {'average': 'vgood',
#                                                                                                                                                             'baverage': 'vgood',
#                                                                                                                                                             'less': 'acc'}},
#                                                                                                                                 'small': {'Number of Doors': {'average': 'acc',
#                                                                                                                                                               'baverage': 'acc',
#                                                                                                                                                               'less': 'unacc',
#                                                                                                                                                               'more': 'acc'}}}},
#                                                                                                  'low': {'luggage Boot Size': {'big': 'vgood',
#                                                                                                                                'med': {'Number of Doors': {'average': 'vgood',
#                                                                                                                                                            'less': 'good',
#                                                                                                                                                            'more': 'vgood'}},
#                                                                                                                                'small': {'Number of Doors': {'average': 'good',
#                                                                                                                                                              'baverage': 'good',
#                                                                                                                                                              'less': 'unacc',
#                                                                                                                                                              'more': 'good'}}}},
#                                                                                                  'med': {'luggage Boot Size': {'big': 'vgood',
#                                                                                                                                'med': {'Number of Doors': {'less': 'good',
#                                                                                                                                                            'more': 'vgood'}},
#                                                                                                                                'small': {'Number of Doors': {'baverage': 'good',
#                                                                                                                                                              'less': 'unacc'}}}},
#                                                                                                  'vhigh': 'acc'}},
#                                                                    'med': {'Maintenance Price': {'high': {'Number of Doors': {'average': 'acc',
#                                                                                                                               'baverage': 'acc',
#                                                                                                                               'less': 'unacc',
#                                                                                                                               'more': 'acc'}},
#                                                                                                  'low': {'luggage Boot Size': {'big': 'vgood',
#                                                                                                                                'med': {'Number of Doors': {'average': 'vgood',
#                                                                                                                                                            'baverage': 'vgood',
#                                                                                                                                                            'less': 'good',
#                                                                                                                                                            'more': 'vgood'}},
#                                                                                                                                'small': {'Number of Doors': {'baverage': 'good',
#                                                                                                                                                              'less': 'unacc',
#                                                                                                                                                              'more': 'good'}}}},
#                                                                                                  'med': {'Number of Doors': {'average': 'vgood',
#                                                                                                                              'baverage': {'luggage Boot Size': {'big': 'vgood',
#                                                                                                                                                                 'small': 'acc'}},
#                                                                                                                              'less': 'acc',
#                                                                                                                              'more': 'acc'}},
#                                                                                                  'vhigh': 'acc'}},
#                                                                    'vhigh': {'Maintenance Price': {'high': 'unacc',
#                                                                                                    'low': 'acc',
#                                                                                                    'med': {'Number of Doors': {'average': 'acc',
#                                                                                                                                'baverage': 'acc',
#                                                                                                                                'less': {'luggage Boot Size': {'med': 'acc',
#                                                                                                                                                               'small': 'unacc'}},
#                                                                                                                                'more': 'acc'}},
#                                                                                                    'vhigh': 'unacc'}}}}}},
#             'low': 'unacc',
#             'med': {'Person Capacity': {'average': {'Buying Price': {'high': {'Maintenance Price': {'high': {'Number of Doors': {'baverage': {'luggage Boot Size': {'big': 'acc',
#                                                                                                                                                                     'med': 'unacc'}},
#                                                                                                                                  'less': 'acc',
#                                                                                                                                  'more': 'acc'}},
#                                                                                                     'low': {'luggage Boot Size': {'big': 'acc',
#                                                                                                                                   'med': {'Number of Doors': {'average': 'acc',
#                                                                                                                                                               'baverage': 'unacc',
#                                                                                                                                                               'less': 'unacc'}},
#                                                                                                                                   'small': 'unacc'}},
#                                                                                                     'med': {'Number of Doors': {'average': 'acc',
#                                                                                                                                 'baverage': {'luggage Boot Size': {'big': 'acc',
#                                                                                                                                                                    'med': 'unacc',
#                                                                                                                                                                    'small': 'unacc'}},
#                                                                                                                                 'less': 'unacc',
#                                                                                                                                 'more': 'acc'}},
#                                                                                                     'vhigh': 'unacc'}},
#                                                                      'low': {'Maintenance Price': {'high': 'acc',
#                                                                                                    'low': {'luggage Boot Size': {'big': 'good',
#                                                                                                                                  'med': 'good',
#                                                                                                                                  'small': 'acc'}},
#                                                                                                    'med': {'Number of Doors': {'average': 'good',
#                                                                                                                                'baverage': {'luggage Boot Size': {'big': 'good',
#                                                                                                                                                                   'med': 'acc',
#                                                                                                                                                                   'small': 'acc'}},
#                                                                                                                                'less': 'acc',
#                                                                                                                                'more': 'good'}},
#                                                                                                    'vhigh': {'Number of Doors': {'average': 'acc',
#                                                                                                                                  'baverage': {'luggage Boot Size': {'big': 'acc',
#                                                                                                                                                                     'med': 'unacc'}},
#                                                                                                                                  'more': 'acc'}}}},
#                                                                      'med': {'Maintenance Price': {'high': {'luggage Boot Size': {'big': 'acc',
#                                                                                                                                   'med': {'Number of Doors': {'baverage': 'unacc',
#                                                                                                                                                               'less': 'unacc',
#                                                                                                                                                               'more': 'acc'}},
#                                                                                                                                   'small': 'unacc'}},
#                                                                                                    'low': {'luggage Boot Size': {'big': 'good',
#                                                                                                                                  'med': {'Number of Doors': {'average': 'good',
#                                                                                                                                                              'baverage': 'acc',
#                                                                                                                                                              'more': 'good'}},
#                                                                                                                                  'small': 'acc'}},
#                                                                                                    'med': 'acc',
#                                                                                                    'vhigh': {'luggage Boot Size': {'big': 'acc',
#                                                                                                                                    'med': {'Number of Doors': {'baverage': 'unacc',
#                                                                                                                                                                'more': 'acc'}},
#                                                                                                                                    'small': 'unacc'}}}},
#                                                                      'vhigh': {'Maintenance Price': {'high': 'unacc',
#                                                                                                      'low': {'luggage Boot Size': {'big': 'acc',
#                                                                                                                                    'med': {'Number of Doors': {'average': 'acc',
#                                                                                                                                                                'baverage': 'unacc',
#                                                                                                                                                                'less': 'unacc',
#                                                                                                                                                                'more': 'acc'}},
#                                                                                                                                    'small': 'unacc'}},
#                                                                                                      'med': {'luggage Boot Size': {'big': 'acc',
#                                                                                                                                    'med': {'Number of Doors': {'average': 'acc',
#                                                                                                                                                                'baverage': 'unacc',
#                                                                                                                                                                'more': 'acc'}},
#                                                                                                                                    'small': 'unacc'}},
#                                                                                                      'vhigh': 'unacc'}}}},
#                                         'less': 'unacc',
#                                         'more': {'Buying Price': {'high': {'luggage Boot Size': {'big': {'Maintenance Price': {'high': 'acc',
#                                                                                                                                'low': 'acc',
#                                                                                                                                'med': 'acc',
#                                                                                                                                'vhigh': 'unacc'}},
#                                                                                                  'med': {'Number of Doors': {'average': {'Maintenance Price': {'high': 'acc',
#                                                                                                                                                                'low': 'acc',
#                                                                                                                                                                'med': 'acc',
#                                                                                                                                                                'vhigh': 'unacc'}},
#                                                                                                                              'baverage': 'acc',
#                                                                                                                              'less': 'unacc',
#                                                                                                                              'more': 'acc'}},
#                                                                                                  'small': 'unacc'}},
#                                                                   'low': {'Maintenance Price': {'high': 'acc',
#                                                                                                 'low': {'Number of Doors': {'average': {'luggage Boot Size': {'big': 'good',
#                                                                                                                                                               'small': 'acc'}},
#                                                                                                                             'baverage': 'acc',
#                                                                                                                             'less': {'luggage Boot Size': {'med': 'acc',
#                                                                                                                                                            'small': 'unacc'}},
#                                                                                                                             'more': 'good'}},
#                                                                                                 'med': {'luggage Boot Size': {'big': 'good',
#                                                                                                                               'med': 'good',
#                                                                                                                               'small': {'Number of Doors': {'average': 'acc',
#                                                                                                                                                             'less': 'unacc',
#                                                                                                                                                             'more': 'acc'}}}},
#                                                                                                 'vhigh': {'Number of Doors': {'average': 'acc',
#                                                                                                                               'baverage': 'acc',
#                                                                                                                               'less': {'luggage Boot Size': {'big': 'acc',
#                                                                                                                                                              'med': 'unacc',
#                                                                                                                                                              'small': 'unacc'}},
#                                                                                                                               'more': 'acc'}}}},
#                                                                   'med': {'Maintenance Price': {'high': {'luggage Boot Size': {'big': 'acc',
#                                                                                                                                'med': {'Number of Doors': {'average': 'acc',
#                                                                                                                                                            'baverage': 'acc',
#                                                                                                                                                            'less': 'unacc',
#                                                                                                                                                            'more': 'acc'}},
#                                                                                                                                'small': 'unacc'}},
#                                                                                                 'low': {'luggage Boot Size': {'big': 'good',
#                                                                                                                               'med': {'Number of Doors': {'average': 'good',
#                                                                                                                                                           'baverage': 'good',
#                                                                                                                                                           'less': 'acc'}},
#                                                                                                                               'small': 'acc'}},
#                                                                                                 'med': {'Number of Doors': {'average': 'acc',
#                                                                                                                             'baverage': 'acc',
#                                                                                                                             'less': {'luggage Boot Size': {'big': 'acc',
#                                                                                                                                                            'med': 'acc',
#                                                                                                                                                            'small': 'unacc'}},
#                                                                                                                             'more': 'acc'}},
#                                                                                                 'vhigh': {'luggage Boot Size': {'big': 'acc',
#                                                                                                                                 'med': 'acc',
#                                                                                                                                 'small': 'unacc'}}}},
#                                                                   'vhigh': {'Maintenance Price': {'high': 'unacc',
#                                                                                                   'low': {'luggage Boot Size': {'big': 'acc',
#                                                                                                                                 'med': 'acc',
#                                                                                                                                 'small': 'unacc'}},
#                                                                                                   'med': {'luggage Boot Size': {'big': 'acc',
#                                                                                                                                 'med': 'acc',
#                                                                                                                                 'small': 'unacc'}},
#                                                                                                   'vhigh': 'unacc'}}}}}}}}
# The prediction accuracy is:  86.57844990548205 %
